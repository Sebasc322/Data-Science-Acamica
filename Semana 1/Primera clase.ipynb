# %%
nombre = "Sebastián"
edad = 26
print(nombre, edad)
# Out:
# Sebastián 26

# %%
print("Mi nombre es", nombre, " y mi edad es", edad)
# Out:
# Mi nombre es Sebastián  y mi edad es 26

# %%
print("Mi nombre es {} y mi edad es {} años".format(nombre,edad))
# Out:
# Mi nombre es Sebastián y mi edad es 26 años

# %%
a = 5
b = a

# %%
b = 3

# %%
a
# Out:
# 5

# %%
edad_compa = 28

# %%
edad_compa < edad
# Out:
# False

# %%
edad = edad + 50

# %%
edad_compa < edad
# Out:
# True

# %% [markdown]
# # N-Gramas: Piensa como un Data Scientist

# %% [markdown]
# ¿Qué preguntas se te ocurren? ¿Existe alguna pregunta de tu profesión que tal vez esta herramienta pueda ayudar a responder?

# %% [markdown]
# ¿Cuando fue la primera vez que se habló de los yacimientos no convencionales y del Fracking?

# %% [markdown]
# ![image.png](attachment:7ac9fcbb-2f82-478f-9c38-7af2d1ff50c5.png)

# %% [markdown]
# ![image.png](attachment:ac9fb31d-bfbb-45e3-98a0-96bfc11499bf.png)

# %% [markdown]
# ¿Cuando se empezó a hablar de Data Science y Data Analytics? ¿Durante el tiempo se incrementó el uso de estas definiciones?

# %% [markdown]
# ![image.png](attachment:93914522-98e5-425d-88a1-b87880983085.png)
